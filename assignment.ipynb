# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
haberman = pd.read_csv('haberman.csv')
haberman.head()
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1

# %%
column_names = ['Age', 'Year', 'Positive_Axillary_Nodes', 'Survival_Status']
haberman.columns = column_names 
haberman.head()
# Out:
#    Age  Year  Positive_Axillary_Nodes  Survival_Status
# 0   30    62                        3                1
# 1   30    65                        0                1
# 2   31    59                        2                1
# 3   31    65                        4                1
# 4   33    58                       10                1

# %%
haberman.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      305 non-null    int64
#  1   Year                     305 non-null    int64
#  2   Positive_Axillary_Nodes  305 non-null    int64
#  3   Survival_Status          305 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
sns.relplot(data=haberman, x="Age", y="Positive_Axillary_Nodes")

# %% [markdown]
# #### people who have maximum positive_auxilary_node is in the age of 40

# %%
sns.relplot(data=haberman, x="Year", y="Positive_Axillary_Nodes")

# %% [markdown]
# #### people with maximum positive_auxilary_node is found in the year 1958

# %%
haberman.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### complete dataset diagram

# %%
sns.countplot(x='Survival_Status',data=haberman)
# Out:
# <AxesSubplot:xlabel='Survival_Status', ylabel='count'>

# %% [markdown]
# #### the patients survived more than 5 years or longer are more compare to  the patient died within 5 years

# %%
sns.boxplot(data=haberman,y="Age")
# Out:
# <AxesSubplot:ylabel='Age'>

# %% [markdown]
# ### the IQR is in the range of 44 to 61

# %%
sns.lineplot(x='Year', y='Positive_Axillary_Nodes', data=haberman)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Positive_Axillary_Nodes'>

# %% [markdown]
# ### positive auxilary node are high in the year 62
